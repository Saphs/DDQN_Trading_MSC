# %%
import os.path
import re
from itertools import chain
from pathlib import Path
import pandas as pd
from matplotlib import pyplot as plt
from pandas import DataFrame

# %%
"""Load files into memory"""

# Baseline results
TEST_RESULT_FOLDER = Path("C:\\Users\\tizia\\PycharmProjects\\DDQN_Trading_MSC\\model_archive\\TestResults\\DensityTests")
GRAPH_OUTPUT = Path("./graphs")
name = "db_density_check"
title = "Deutsche Bank"
OPTIMIZATION_TESTS = TEST_RESULT_FOLDER.joinpath(name)
METRICS_RELATIVE = "final\\validation\\metrics.csv"



required_columns = ['model_name', 'mode', 'return', 'total_volatility']

result_metrics = []
ref_bh = None
if os.path.exists(OPTIMIZATION_TESTS):
    test_directories = os.listdir(OPTIMIZATION_TESTS)
    print(f"Found {len(test_directories)} test folders:")
    print(test_directories)
    for i, test in enumerate(test_directories):
        test_path = OPTIMIZATION_TESTS.joinpath(test).joinpath(METRICS_RELATIVE)
        sample_df = pd.read_csv(test_path)
        print(sample_df)
        if i == 0:
            ref_bh = sample_df.head(1)
        sample_df = sample_df.tail(2)
        sample_df['mode'] = sample_df['evaluation_mode'].apply(lambda x: "Eval" if x == True else "Train")
        sample_df = sample_df[required_columns]
        result_metrics.append(sample_df)

else:
    print(f"Folder: {OPTIMIZATION_TESTS} was not found. Nothing was loaded.")

chunk_size = 3
chunked_metrics = []
for i in range(0, len(result_metrics), chunk_size):
    chunk = result_metrics[i:i + chunk_size]
    chunked_metrics.append(chunk)

for i, x in enumerate([1, 3, 5, 10, 20, 30]):
    for j in range(chunk_size):
        chunked_metrics[i][j]['density'] = x

metrics = pd.concat(list(chain(*chunked_metrics)))
metrics
# Out:
# Found 18 test folders:
# ['1695788469', '1695792000', '1695795366', '1695798535', '1695799611', '1695800684', '1695801747', '1695802369', '1695802982', '1695803597', '1695803907', '1695804222', '1695804529', '1695804665', '1695804798', '1695804933', '1695805024', '1695805114']
#    Unnamed: 0                     model_name evaluation_mode          stock
# 0           0                   (*) Buy&Hold             NaN  Deutsche Bank  \
# 1           1  best_1473_for-seed_1234567890           False  Deutsche Bank
# 2           2  best_1473_for-seed_1234567890            True  Deutsche Bank
#
#        V_i      V_f   profit    return  amean_return  gmean_return  ...
# 0  10000.0  9875.96  -124.04 -0.012404      0.000364     -0.000011  ...  \
# 1  10000.0  2285.08 -7714.92 -0.771492     -0.001176     -0.001357  ...
# 2  10000.0  9105.93  -894.07 -0.089407     -0.000066     -0.000086  ...
#
#    log_return  log_rate_of_return  daily_volatility  total_volatility
# 0   -0.012482           -0.000011          0.027420          0.904037  \
# 1   -1.476184           -0.001358          0.019067          0.628640
# 2   -0.093660           -0.000086          0.006424          0.211796
#
#    sharpe_ratio  value_at_risk_per_day  value_at_risk  tried_transactions
# 0     -1.594541              -0.001248      -1.345502                   1  \
# 1     -3.500593              -0.001929      -0.936528                 667
# 2     -7.169779              -0.000153      -0.144255                 503
#
#    transactions  transactions_per_30_t
# 0             1                   0.03
# 1           274                   7.56
# 2            90                   2.48
#
# [3 rows x 21 columns]
#    Unnamed: 0                     model_name evaluation_mode          stock
# 0           0                   (*) Buy&Hold             NaN  Deutsche Bank  \
# 1           1  best_1337_for-seed_1234567891           False  Deutsche Bank
# 2           2  best_1337_for-seed_1234567891            True  Deutsche Bank
#
#        V_i      V_f   profit    return  amean_return  gmean_return  ...
# 0  10000.0  9875.96  -124.04 -0.012404      0.000364     -0.000011  ...  \
# 1  10000.0  2791.06 -7208.94 -0.720894     -0.001030     -0.001173  ...
# 2  10000.0  8417.98 -1582.02 -0.158202     -0.000080     -0.000158  ...
#
#    log_return  log_rate_of_return  daily_volatility  total_volatility
# 0   -0.012482           -0.000011          0.027420          0.904037  \
# 1   -1.276164           -0.001174          0.016967          0.559400
# 2   -0.172215           -0.000158          0.012533          0.413216
#
#    sharpe_ratio  value_at_risk_per_day  value_at_risk  tried_transactions
# 0     -1.594541              -0.001248      -1.345502                   1  \
# 1     -3.843430              -0.001627      -0.832347                 750
# 2     -3.841388              -0.000415      -0.373684                 625
#
#    transactions  transactions_per_30_t
# 0             1                   0.03
# 1           346                   9.55
# 2           236                   6.51
#
# [3 rows x 21 columns]
#    Unnamed: 0                     model_name evaluation_mode          stock
# 0           0                   (*) Buy&Hold             NaN  Deutsche Bank  \
# 1           1  best_1439_for-seed_1234567892           False  Deutsche Bank
# 2           2  best_1439_for-seed_1234567892            True  Deutsche Bank
#
#        V_i      V_f   profit    return  amean_return  gmean_return  ...
# 0  10000.0  9875.96  -124.04 -0.012404      0.000364     -0.000011  ...  \
# 1  10000.0  2745.38 -7254.62 -0.725462     -0.001057     -0.001188  ...
# 2  10000.0  9431.43  -568.57 -0.056857     -0.000022     -0.000054  ...
#
#    log_return  log_rate_of_return  daily_volatility  total_volatility
# 0   -0.012482           -0.000011          0.027420          0.904037  \
# 1   -1.292667           -0.001189          0.016244          0.535556
# 2   -0.058537           -0.000054          0.007942          0.261859
#
#    sharpe_ratio  value_at_risk_per_day  value_at_risk  tried_transactions
# 0     -1.594541              -0.001248      -1.345502                   1  \
# 1     -4.023080              -0.001603      -0.808714                 700
# 2     -5.674722              -0.000157      -0.154756                 774
#
#    transactions  transactions_per_30_t
# 0             1                   0.03
# 1           298                   8.22
# 2           134                   3.70
#
# [3 rows x 21 columns]
#    Unnamed: 0                     model_name evaluation_mode          stock
# 0           0                   (*) Buy&Hold             NaN  Deutsche Bank  \
# 1           1  best_1150_for-seed_1234567890           False  Deutsche Bank
# 2           2  best_1150_for-seed_1234567890            True  Deutsche Bank
#
#        V_i      V_f   profit    return  amean_return  gmean_return  ...
# 0  10000.0  9943.86   -56.14 -0.005614      0.001064     -0.000016  ...  \
# 1  10000.0  5571.42 -4428.58 -0.442858     -0.001025     -0.001610  ...
# 2  10000.0  8960.15 -1039.85 -0.103985      0.000741     -0.000302  ...
#
#    log_return  log_rate_of_return  daily_volatility  total_volatility
# 0   -0.005629           -0.000016          0.046445          0.884901  \
# 1   -0.584935           -0.001611          0.034348          0.654421
# 2   -0.109798           -0.000302          0.045661          0.869956
#
#    sharpe_ratio  value_at_risk_per_day  value_at_risk  tried_transactions
# 0     -0.395381              -0.003563      -1.288648                   1  \
# 1     -1.202769              -0.003495      -0.857479                 203
# 2     -0.515249              -0.003718      -1.258387                 313
#
#    transactions  transactions_per_30_t
# 0             1                   0.08
# 1            68                   5.62
# 2            25                   2.07
#
# [3 rows x 21 columns]
#    Unnamed: 0                     model_name evaluation_mode          stock
# 0           0                   (*) Buy&Hold             NaN  Deutsche Bank  \
# 1           1  best_1259_for-seed_1234567891           False  Deutsche Bank
# 2           2  best_1259_for-seed_1234567891            True  Deutsche Bank
#
#        V_i      V_f   profit    return  amean_return  gmean_return  ...
# 0  10000.0  9943.86   -56.14 -0.005614      0.001064     -0.000016  ...  \
# 1  10000.0  6009.42 -3990.58 -0.399058     -0.000699     -0.001402  ...
# 2  10000.0  9306.18  -693.82 -0.069382      0.000793     -0.000198  ...
#
#    log_return  log_rate_of_return  daily_volatility  total_volatility
# 0   -0.005629           -0.000016          0.046445          0.884901  \
# 1   -0.509257           -0.001403          0.037502          0.714500
# 2   -0.071906           -0.000198          0.044621          0.850138
#
#    sharpe_ratio  value_at_risk_per_day  value_at_risk  tried_transactions
# 0     -0.395381              -0.003563      -1.288648                   1  \
# 1     -1.040331              -0.003663      -0.953646                 200
# 2     -0.486558              -0.003464      -1.199190                 256
#
#    transactions  transactions_per_30_t
# 0             1                   0.08
# 1            90                   7.44
# 2            13                   1.07
#
# [3 rows x 21 columns]
#    Unnamed: 0                     model_name evaluation_mode          stock
# 0           0                   (*) Buy&Hold             NaN  Deutsche Bank  \
# 1           1  best_1367_for-seed_1234567892           False  Deutsche Bank
# 2           2  best_1367_for-seed_1234567892            True  Deutsche Bank
#
#        V_i      V_f   profit    return  amean_return  gmean_return  ...
# 0  10000.0  9943.86   -56.14 -0.005614      0.001064     -0.000016  ...  \
# 1  10000.0  5103.17 -4896.83 -0.489683     -0.001290     -0.001852  ...
# 2  10000.0  8312.55 -1687.45 -0.168745      0.000420     -0.000509  ...
#
#    log_return  log_rate_of_return  daily_volatility  total_volatility
# 0   -0.005629           -0.000016          0.046445          0.884901  \
# 1   -0.672723           -0.001853          0.033643          0.640978
# 2   -0.184818           -0.000509          0.043237          0.823772
#
#    sharpe_ratio  value_at_risk_per_day  value_at_risk  tried_transactions
# 0     -0.395381              -0.003563      -1.288648                   1  \
# 1     -1.301047              -0.003651      -0.851599                 231
# 2     -0.622750              -0.003562      -1.145935                 327
#
#    transactions  transactions_per_30_t
# 0             1                   0.08
# 1            86                   7.11
# 2            11                   0.91
#
# [3 rows x 21 columns]
#    Unnamed: 0                    model_name evaluation_mode          stock
# 0           0                  (*) Buy&Hold             NaN  Deutsche Bank  \
# 1           1  best_732_for-seed_1234567890           False  Deutsche Bank
# 2           2  best_732_for-seed_1234567890            True  Deutsche Bank
#
#        V_i       V_f   profit    return  amean_return  gmean_return  ...
# 0  10000.0  10091.97    91.97  0.009197      0.001997      0.000042  ...  \
# 1  10000.0   4787.90 -5212.10 -0.521210     -0.002327     -0.003373  ...
# 2  10000.0   5007.69 -4992.31 -0.499231     -0.001758     -0.003168  ...
#
#    log_return  log_rate_of_return  daily_volatility  total_volatility
# 0    0.009155            0.000042          0.062832          0.927698  \
# 1   -0.736494           -0.003378          0.046261          0.683038
# 2   -0.691611           -0.003173          0.053499          0.789903
#
#    sharpe_ratio  value_at_risk_per_day  value_at_risk  tried_transactions
# 0     -0.193128              -0.006454      -1.414934                   1  \
# 1     -1.038847              -0.006737      -0.932595                 128
# 2     -0.870477              -0.007706      -1.131188                 151
#
#    transactions  transactions_per_30_t
# 0             1                   0.14
# 1            46                   6.33
# 2            61                   8.39
#
# [3 rows x 21 columns]
#    Unnamed: 0                     model_name evaluation_mode          stock
# 0           0                   (*) Buy&Hold             NaN  Deutsche Bank  \
# 1           1  best_1439_for-seed_1234567891           False  Deutsche Bank
# 2           2  best_1439_for-seed_1234567891            True  Deutsche Bank
#
#        V_i       V_f   profit    return  amean_return  gmean_return  ...
# 0  10000.0  10091.97    91.97  0.009197      0.001997      0.000042  ...  \
# 1  10000.0   3018.86 -6981.14 -0.698114     -0.004469     -0.005479  ...
# 2  10000.0   5519.75 -4480.25 -0.448025     -0.001154     -0.002722  ...
#
#    log_return  log_rate_of_return  daily_volatility  total_volatility
# 0    0.009155            0.000042          0.062832          0.927698  \
# 1   -1.197707           -0.005494          0.045377          0.669979
# 2   -0.594253           -0.002726          0.056389          0.832580
#
#    sharpe_ratio  value_at_risk_per_day  value_at_risk  tried_transactions
# 0     -0.193128              -0.006454      -1.414934                   1  \
# 1     -1.323139              -0.008617      -0.968721                 118
# 2     -0.764355              -0.007799      -1.215203                 201
#
#    transactions  transactions_per_30_t
# 0             1                   0.14
# 1            44                   6.06
# 2            43                   5.92
#
# [3 rows x 21 columns]
#    Unnamed: 0                     model_name evaluation_mode          stock
# 0           0                   (*) Buy&Hold             NaN  Deutsche Bank  \
# 1           1  best_1035_for-seed_1234567892           False  Deutsche Bank
# 2           2  best_1035_for-seed_1234567892            True  Deutsche Bank
#
#        V_i       V_f   profit    return  amean_return  gmean_return  ...
# 0  10000.0  10091.97    91.97  0.009197      0.001997      0.000042  ...  \
# 1  10000.0   7484.83 -2515.17 -0.251517     -0.000256     -0.001328  ...
# 2  10000.0   7671.43 -2328.57 -0.232857      0.000350     -0.001215  ...
#
#    log_return  log_rate_of_return  daily_volatility  total_volatility
# 0    0.009155            0.000042          0.062832          0.927698  \
# 1   -0.289706           -0.001329          0.046548          0.687267
# 2   -0.265083           -0.001216          0.056308          0.831375
#
#    sharpe_ratio  value_at_risk_per_day  value_at_risk  tried_transactions
# 0     -0.193128              -0.006454      -1.414934                   1  \
# 1     -0.640039              -0.004830      -0.855582                 147
# 2     -0.506653              -0.006362      -1.176163                 176
#
#    transactions  transactions_per_30_t
# 0             1                   0.14
# 1            44                   6.06
# 2            23                   3.17
#
# [3 rows x 21 columns]
#    Unnamed: 0                     model_name evaluation_mode          stock
# 0           0                   (*) Buy&Hold             NaN  Deutsche Bank  \
# 1           1  best_1078_for-seed_1234567890           False  Deutsche Bank
# 2           2  best_1078_for-seed_1234567890            True  Deutsche Bank
#
#        V_i      V_f   profit    return  amean_return  gmean_return  ...
# 0  10000.0  9859.88  -140.12 -0.014012      0.003962     -0.000129  ...  \
# 1  10000.0  7653.41 -2346.59 -0.234659     -0.000798     -0.002451  ...
# 2  10000.0  7949.57 -2050.43 -0.205043      0.000248     -0.002103  ...
#
#    log_return  log_rate_of_return  daily_volatility  total_volatility
# 0   -0.014111           -0.000129          0.091060          0.950693  \
# 1   -0.267434           -0.002454          0.058632          0.612137
# 2   -0.229468           -0.002105          0.069479          0.725385
#
#    sharpe_ratio  value_at_risk_per_day  value_at_risk  tried_transactions
# 0     -0.095485              -0.013757      -1.487339                   1  \
# 1     -0.508749              -0.007961      -0.707361                  59
# 2     -0.388494              -0.009897      -0.921803                  85
#
#    transactions  transactions_per_30_t
# 0             1                   0.28
# 1            23                   6.33
# 2            35                   9.63
#
# [3 rows x 21 columns]
#    Unnamed: 0                    model_name evaluation_mode          stock
# 0           0                  (*) Buy&Hold             NaN  Deutsche Bank  \
# 1           1  best_671_for-seed_1234567891           False  Deutsche Bank
# 2           2  best_671_for-seed_1234567891            True  Deutsche Bank
#
#        V_i      V_f   profit    return  amean_return  gmean_return  ...
# 0  10000.0  9859.88  -140.12 -0.014012      0.003962     -0.000129  ...  \
# 1  10000.0  6338.38 -3661.62 -0.366162     -0.002296     -0.004174  ...
# 2  10000.0  6052.54 -3947.46 -0.394746     -0.002491     -0.004596  ...
#
#    log_return  log_rate_of_return  daily_volatility  total_volatility
# 0   -0.014111           -0.000129          0.091060          0.950693  \
# 1   -0.455961           -0.004183          0.062433          0.651822
# 2   -0.502107           -0.004606          0.066024          0.689309
#
#    sharpe_ratio  value_at_risk_per_day  value_at_risk  tried_transactions
# 0     -0.095485              -0.013757      -1.487339                   1  \
# 1     -0.679520              -0.010325      -0.826342                  62
# 2     -0.684033              -0.011463      -0.904191                  69
#
#    transactions  transactions_per_30_t
# 0             1                   0.28
# 1            27                   7.43
# 2            23                   6.33
#
# [3 rows x 21 columns]
#    Unnamed: 0                     model_name evaluation_mode          stock
# 0           0                   (*) Buy&Hold             NaN  Deutsche Bank  \
# 1           1  best_1199_for-seed_1234567892           False  Deutsche Bank
# 2           2  best_1199_for-seed_1234567892            True  Deutsche Bank
#
#        V_i      V_f   profit    return  amean_return  gmean_return  ...
# 0  10000.0  9859.88  -140.12 -0.014012      0.003962     -0.000129  ...  \
# 1  10000.0  5417.55 -4582.45 -0.458245     -0.003957     -0.005608  ...
# 2  10000.0  6954.13 -3045.87 -0.304587     -0.001194     -0.003327  ...
#
#    log_return  log_rate_of_return  daily_volatility  total_volatility
# 0   -0.014111           -0.000129          0.091060          0.950693  \
# 1   -0.612941           -0.005623          0.058866          0.614578
# 2   -0.363249           -0.003333          0.066415          0.693395
#
#    sharpe_ratio  value_at_risk_per_day  value_at_risk  tried_transactions
# 0     -0.095485              -0.013757      -1.487339                   1  \
# 1     -0.870531              -0.010977      -0.797888                  79
# 2     -0.549977              -0.010361      -0.884227                  80
#
#    transactions  transactions_per_30_t
# 0             1                   0.28
# 1            35                   9.63
# 2            31                   8.53
#
# [3 rows x 21 columns]
#    Unnamed: 0                    model_name evaluation_mode          stock
# 0           0                  (*) Buy&Hold             NaN  Deutsche Bank  \
# 1           1  best_184_for-seed_1234567890           False  Deutsche Bank
# 2           2  best_184_for-seed_1234567890            True  Deutsche Bank
#
#        V_i      V_f   profit    return  amean_return  gmean_return  ...
# 0  10000.0  9994.12    -5.88 -0.000588      0.007488     -0.000011  ...  \
# 1  10000.0  8711.73 -1288.27 -0.128827     -0.000336     -0.002504  ...
# 2  10000.0  7180.46 -2819.54 -0.281954     -0.002873     -0.006004  ...
#
#    log_return  log_rate_of_return  daily_volatility  total_volatility
# 0   -0.000588           -0.000011          0.124263          0.921558  \
# 1   -0.137915           -0.002508          0.066157          0.490632
# 2   -0.331222           -0.006022          0.079939          0.592846
#
#    sharpe_ratio  value_at_risk_per_day  value_at_risk  tried_transactions
# 0     -0.027722              -0.025408      -1.396971                   1  \
# 1     -0.313446              -0.009538      -0.461569                  45
# 2     -0.517696              -0.016035      -0.692909                  43
#
#    transactions  transactions_per_30_t
# 0             1                   0.55
# 1             5                   2.73
# 2             7                   3.82
#
# [3 rows x 21 columns]
#    Unnamed: 0                   model_name evaluation_mode          stock
# 0           0                 (*) Buy&Hold             NaN  Deutsche Bank  \
# 1           1  best_95_for-seed_1234567891           False  Deutsche Bank
# 2           2  best_95_for-seed_1234567891            True  Deutsche Bank
#
#        V_i       V_f   profit    return  amean_return  gmean_return  ...
# 0  10000.0   9994.12    -5.88 -0.000588      0.007488     -0.000011  ...  \
# 1  10000.0  15796.53  5796.53  0.579653      0.010046      0.008347  ...
# 2  10000.0  13918.28  3918.28  0.391828      0.007874      0.006029  ...
#
#    log_return  log_rate_of_return  daily_volatility  total_volatility
# 0   -0.000588           -0.000011          0.124263          0.921558  \
# 1    0.457205            0.008313          0.057940          0.429692
# 2    0.330618            0.006011          0.060480          0.448532
#
#    sharpe_ratio  value_at_risk_per_day  value_at_risk  tried_transactions
# 0     -0.027722              -0.025408      -1.396971                   1  \
# 1      1.290907               0.002342       0.026883                  44
# 2      0.817931              -0.000352      -0.114833                  45
#
#    transactions  transactions_per_30_t
# 0             1                   0.55
# 1            17                   9.27
# 2            17                   9.27
#
# [3 rows x 21 columns]
#    Unnamed: 0                    model_name evaluation_mode          stock
# 0           0                  (*) Buy&Hold             NaN  Deutsche Bank  \
# 1           1  best_938_for-seed_1234567892           False  Deutsche Bank
# 2           2  best_938_for-seed_1234567892            True  Deutsche Bank
#
#        V_i       V_f   profit    return  amean_return  gmean_return  ...
# 0  10000.0   9994.12    -5.88 -0.000588      0.007488     -0.000011  ...  \
# 1  10000.0  10472.18   472.18  0.047218      0.002168      0.000839  ...
# 2  10000.0   6537.35 -3462.65 -0.346265     -0.001937     -0.007698  ...
#
#    log_return  log_rate_of_return  daily_volatility  total_volatility
# 0   -0.000588           -0.000011          0.124263          0.921558  \
# 1    0.046138            0.000839          0.051290          0.380378
# 2   -0.425053           -0.007728          0.110199          0.817261
#
#    sharpe_ratio  value_at_risk_per_day  value_at_risk  tried_transactions
# 0     -0.027722              -0.025408      -1.396971                   1  \
# 1      0.058517              -0.003531      -0.208733                  39
# 2     -0.454231              -0.026825      -1.161900                  33
#
#    transactions  transactions_per_30_t
# 0             1                   0.55
# 1            11                   6.00
# 2             9                   4.91
#
# [3 rows x 21 columns]
#    Unnamed: 0                     model_name evaluation_mode          stock
# 0           0                   (*) Buy&Hold             NaN  Deutsche Bank  \
# 1           1  best_1113_for-seed_1234567890           False  Deutsche Bank
# 2           2  best_1113_for-seed_1234567890            True  Deutsche Bank
#
#        V_i       V_f   profit    return  amean_return  gmean_return  ...
# 0  10000.0  10041.77    41.77  0.004177      0.010804      0.000113  ...  \
# 1  10000.0   8443.45 -1556.55 -0.155655      0.002819     -0.004562  ...
# 2  10000.0   8182.09 -1817.91 -0.181791      0.002941     -0.005408  ...
#
#    log_return  log_rate_of_return  daily_volatility  total_volatility
# 0    0.004168            0.000113          0.149208          0.907598  \
# 1   -0.169194           -0.004573          0.124571          0.757733
# 2   -0.200638           -0.005423          0.132296          0.804724
#
#    sharpe_ratio  value_at_risk_per_day  value_at_risk  tried_transactions
# 0     -0.022899              -0.036524      -1.354536                   1  \
# 1     -0.238363              -0.029519      -0.982119                  22
# 2     -0.256922              -0.033481      -1.100676                  24
#
#    transactions  transactions_per_30_t
# 0             1                   0.81
# 1            11                   8.92
# 2             5                   4.05
#
# [3 rows x 21 columns]
#    Unnamed: 0                     model_name evaluation_mode          stock
# 0           0                   (*) Buy&Hold             NaN  Deutsche Bank  \
# 1           1  best_1174_for-seed_1234567891           False  Deutsche Bank
# 2           2  best_1174_for-seed_1234567891            True  Deutsche Bank
#
#        V_i       V_f   profit    return  amean_return  gmean_return  ...
# 0  10000.0  10041.77    41.77  0.004177      0.010804      0.000113  ...  \
# 1  10000.0  14463.60  4463.60  0.446360      0.017773      0.010024  ...
# 2  10000.0  16279.17  6279.17  0.627917      0.022171      0.013257  ...
#
#    log_return  log_rate_of_return  daily_volatility  total_volatility
# 0    0.004168            0.000113          0.149208          0.907598  \
# 1    0.369050            0.009974          0.126863          0.771675
# 2    0.487301            0.013170          0.135717          0.825536
#
#    sharpe_ratio  value_at_risk_per_day  value_at_risk  tried_transactions
# 0     -0.022899              -0.036524      -1.354536                   1  \
# 1      0.546084              -0.017720      -0.877567                  25
# 2      0.730383              -0.018839      -1.011434                  22
#
#    transactions  transactions_per_30_t
# 0             1                   0.81
# 1             5                   4.05
# 2             5                   4.05
#
# [3 rows x 21 columns]
#    Unnamed: 0                     model_name evaluation_mode          stock
# 0           0                   (*) Buy&Hold             NaN  Deutsche Bank  \
# 1           1  best_1094_for-seed_1234567892           False  Deutsche Bank
# 2           2  best_1094_for-seed_1234567892            True  Deutsche Bank
#
#        V_i       V_f  profit    return  amean_return  gmean_return  ...
# 0  10000.0  10041.77   41.77  0.004177      0.010804      0.000113  ...  \
# 1  10000.0   9063.04 -936.96 -0.093696      0.007168     -0.002655  ...
# 2  10000.0  10891.76  891.76  0.089176      0.012555      0.002311  ...
#
#    log_return  log_rate_of_return  daily_volatility  total_volatility
# 0    0.004168            0.000113          0.149208          0.907598  \
# 1   -0.098381           -0.002659          0.143151          0.870755
# 2    0.085421            0.002309          0.145972          0.887911
#
#    sharpe_ratio  value_at_risk_per_day  value_at_risk  tried_transactions
# 0     -0.022899              -0.036524      -1.354536                   1  \
# 1     -0.136268              -0.035982      -1.259261                  25
# 2      0.072322              -0.033074      -1.286785                  28
#
#    transactions  transactions_per_30_t
# 0             1                   0.81
# 1             9                   7.30
# 2             5                   4.05
#
# [3 rows x 21 columns]
#                       model_name   mode    return  total_volatility  density
# 1  best_1473_for-seed_1234567890  Train -0.771492          0.628640        1
# 2  best_1473_for-seed_1234567890   Eval -0.089407          0.211796        1
# 1  best_1337_for-seed_1234567891  Train -0.720894          0.559400        1
# 2  best_1337_for-seed_1234567891   Eval -0.158202          0.413216        1
# 1  best_1439_for-seed_1234567892  Train -0.725462          0.535556        1
# 2  best_1439_for-seed_1234567892   Eval -0.056857          0.261859        1
# 1  best_1150_for-seed_1234567890  Train -0.442858          0.654421        3
# 2  best_1150_for-seed_1234567890   Eval -0.103985          0.869956        3
# 1  best_1259_for-seed_1234567891  Train -0.399058          0.714500        3
# 2  best_1259_for-seed_1234567891   Eval -0.069382          0.850138        3
# 1  best_1367_for-seed_1234567892  Train -0.489683          0.640978        3
# 2  best_1367_for-seed_1234567892   Eval -0.168745          0.823772        3
# 1   best_732_for-seed_1234567890  Train -0.521210          0.683038        5
# 2   best_732_for-seed_1234567890   Eval -0.499231          0.789903        5
# 1  best_1439_for-seed_1234567891  Train -0.698114          0.669979        5
# 2  best_1439_for-seed_1234567891   Eval -0.448025          0.832580        5
# 1  best_1035_for-seed_1234567892  Train -0.251517          0.687267        5
# 2  best_1035_for-seed_1234567892   Eval -0.232857          0.831375        5
# 1  best_1078_for-seed_1234567890  Train -0.234659          0.612137       10
# 2  best_1078_for-seed_1234567890   Eval -0.205043          0.725385       10
# 1   best_671_for-seed_1234567891  Train -0.366162          0.651822       10
# 2   best_671_for-seed_1234567891   Eval -0.394746          0.689309       10
# 1  best_1199_for-seed_1234567892  Train -0.458245          0.614578       10
# 2  best_1199_for-seed_1234567892   Eval -0.304587          0.693395       10
# 1   best_184_for-seed_1234567890  Train -0.128827          0.490632       20
# 2   best_184_for-seed_1234567890   Eval -0.281954          0.592846       20
# 1    best_95_for-seed_1234567891  Train  0.579653          0.429692       20
# 2    best_95_for-seed_1234567891   Eval  0.391828          0.448532       20
# 1   best_938_for-seed_1234567892  Train  0.047218          0.380378       20
# 2   best_938_for-seed_1234567892   Eval -0.346265          0.817261       20
# 1  best_1113_for-seed_1234567890  Train -0.155655          0.757733       30
# 2  best_1113_for-seed_1234567890   Eval -0.181791          0.804724       30
# 1  best_1174_for-seed_1234567891  Train  0.446360          0.771675       30
# 2  best_1174_for-seed_1234567891   Eval  0.627917          0.825536       30
# 1  best_1094_for-seed_1234567892  Train -0.093696          0.870755       30
# 2  best_1094_for-seed_1234567892   Eval  0.089176          0.887911       30

# %%
"""Make box plots and lines"""
#metrics = metrics[metrics['mode'] == 'Train']


fig, ax = plt.subplots(figsize=(12, 5))
#metrics.sort_values(by=['op_space', 'window_size'])
metrics.boxplot(column=['return'], by=['mode', 'density'], ax=ax)
ax.axhline(y=ref_bh['return'][0], color='red', linestyle='dashed', label='Buy&Hold Return', zorder=-1)
plt.legend()
plt.suptitle('')
plt.title(f'Return comparison ({title})', fontsize=18)
plt.tick_params(axis='both', which='major', labelsize=12)
plt.xticks(rotation=45)
plt.xlabel('Tuple of (Mode, Density)', fontsize=14)
plt.ylabel('Return factor', fontsize=14)
plt.tight_layout()
#plt.show()
plt.savefig(GRAPH_OUTPUT.joinpath(f"{name}_density_return_comp.png"))
plt.close()

fig, ax = plt.subplots(figsize=(12, 5))
metrics.boxplot(column=['total_volatility'], by=['mode', 'density'], ax=ax)
ax.axhline(y=ref_bh['total_volatility'][0], color='red', linestyle='dashed', label='Buy&Hold Volatility')
plt.legend()
plt.suptitle('')
plt.title(f'Volatility comparison ({title})', fontsize=18)
plt.tick_params(axis='both', which='major', labelsize=12)
plt.xticks(rotation=45)
plt.xlabel('Tuple of (Mode, Density)', fontsize=14)
plt.ylabel('Total Volatility', fontsize=14)
plt.tight_layout()
#plt.show()
plt.savefig(GRAPH_OUTPUT.joinpath(f"{name}_density_vol_comp.png"))
plt.close()
